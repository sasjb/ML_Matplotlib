# %% [markdown]
# Show Figure

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg
var = mpimg.imread("pie_chart.png")
var
# Out:
# array([[[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
# ...

# %%
var.shape
# Out:
# (480, 640, 4)

# %%
type(var)
# Out:
# numpy.ndarray

# %%
var.ndim
# Out:
# 3

# %%
plt.axis("off")
plt.imshow(var)
plt.show()

# %%
plt.axis("off")
plt.imshow(var)
plt.colorbar()
plt.show()

# %%
plt.axis("off")
img = mpimg.imread("D:\media\Pictures\Function\SS\DSC_0032.jpg")
plt.imshow(img)
plt.show()

# %%
single_channel_img = img[:,:,1]
plt.axis("off")
img = mpimg.imread("D:\media\Pictures\Function\SS\DSC_0032.jpg")
plt.imshow(single_channel_img, cmap = "hot")
plt.colorbar()
plt.show()

# %%
single_channel_img = img[:,:,1]
plt.axis("off")
img = mpimg.imread("D:\media\Pictures\Function\SS\DSC_0032.jpg")
plt.imshow(single_channel_img, cmap = "Oranges_r")
plt.colorbar()
plt.show()
